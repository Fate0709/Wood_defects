# %% [markdown]
# <a href="https://colab.research.google.com/github/Fate0709/Wood_defects/blob/main/Untitled27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.1/562.1 kB 20.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.7/201.7 kB 12.0 MB/s eta 0:00:00
# ...

# %%
# !pip install IPython
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 59.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display,Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics YOLOv8.0.91 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.4/78.2 GB disk)

# %%
# !pip install roboflow --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 7.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.3 MB/s eta 0:00:00
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="esmmdNlvZpd6N44rw9l7")
project = rf.workspace("rtech").project("wood-defcts-4000")
dataset = project.version(2).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.91, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to Wood-defcts-4000-2 in yolov8:: 100%|██████████| 4086/4086 [00:01<00:00, 2400.07it/s]

# %%
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=200 imgsz=640
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 22.8MB/s]
# Ultralytics YOLOv8.0.91 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename=f'/content/runs/detect/train/confusion_matrix.png',width=600)

# %%
Image(filename=f'/content/runs/detect/train/results.png',width=600)

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics YOLOv8.0.91 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/Wood-defcts-4000-2/valid/labels.cache... 125 images, 0 backgrounds, 0 corrupt: 100% 125/125 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:05<00:00,  1.36it/s]
#                    all        125        215      0.938      0.896      0.937      0.565
#              Dead knot        125         57      0.916      0.842      0.905      0.511
#        Intergrown knot        125        158       0.96      0.949       0.97      0.619
# Speed: 3.9ms preprocess, 12.6ms inference, 0.0ms loss, 5.2ms postprocess per image
# Results saved to runs/detect/val

# %%
# !yolo task=detect mode=predict  model=/content/runs/detect/train/weights/best.pt conf=0.5 source={dataset.location}/valid/images
# Out:
# Ultralytics YOLOv8.0.91 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/125 /content/Wood-defcts-4000-2/valid/images/000020_jpg.rf.deb3d18a2e9d53eae036e6443f07340c.jpg: 640x640 1 Intergrown knot, 17.0ms
# image 2/125 /content/Wood-defcts-4000-2/valid/images/000026_jpg.rf.f64d4c1b6367322eb35cb03bd3a621d2.jpg: 640x640 1 Intergrown knot, 16.2ms
# image 3/125 /content/Wood-defcts-4000-2/valid/images/000033_jpg.rf.47c0777b768f9eb4587500f6d660153e.jpg: 640x640 1 Intergrown knot, 16.2ms
# image 4/125 /content/Wood-defcts-4000-2/valid/images/000036_jpg.rf.a4f70fff0c15b2e15205357413014ff3.jpg: 640x640 1 Dead knot, 16.3ms
# image 5/125 /content/Wood-defcts-4000-2/valid/images/000037_jpg.rf.de15076ef518f83559b2a1df35e16817.jpg: 640x640 1 Dead knot, 16.2ms
# ...

# %%
import glob
from IPython.display import display,Image

for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:10]:
  display(Image(filename=image_path,height=600))
  print("\n")

# %%
from google.colab import files
files.download('./runs/detect/train/weights/best.pt')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !nvidia-smi
# Out:
# Tue May  2 10:02:17 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
